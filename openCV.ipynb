# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('data/puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
#Matpotlib order to show image is Red Green Blue
#openCv order to show image is Blue Green Red

# %%
transform_color = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(transform_color)

# %%
img_grey = cv2.imread('data/puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_grey,'grey')

# %%
transform_color.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(transform_color,(1000,300))#first para meter is widht seconmd is hieght

# %%
plt.imshow(new_img)

# %%
# we size the size of image with ratio
w_ratio = 0.5 #50% size of original image
h_ratio = 0.2 #20% size of original image

# %%
new_img = cv2.resize(transform_color,(0,0),transform_color,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (260, 975, 3)

# %%
new_image=cv2.flip(transform_color,1)
plt.imshow(new_image)

# %%
cv2.imwrite('data/new_image.jpg',transform_color)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(transform_color)
